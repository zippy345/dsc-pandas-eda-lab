# %% [markdown]
# # PROJECT 1
# ## EDA WITH PANDAS LAB -AMES HOUSING DATASET.
#
# ### Introduction
#
# In this section, you've learned a lot about importing, cleaning up, analyzing (using descriptive statistics) and visualizing data. In this cumulative lab, you'll get a chance to practice all of these skills with the Ames Housing dataset, which contains information about home sales in Ames, Iowa between 2006 and 2010.
#
# ## Objectives
#
# You will be able to:
#
# * Practice loading data with pandas
# * Practice calculating measures of centrality and dispersion with pandas
# * Practice creating subsets of data with pandas
# * Practice using data visualizations to explore data, and interpreting those visualizations
# * Perform a full exploratory data analysis process to gain insight about a dataset

# %% [markdown]
# ## Your Task: Explore the Ames Housing Dataset with Pandas
#
# ![aerial photo of a neighborhood](images/neighborhood_aerial.jpg)
#
# Photo by <a href="https://unsplash.com/@mattdonders?utm_source=unsplash&utm_medium=referral&utm_content=creditCopyText">Matt Donders</a> on <a href="/@mattdonders?utm_source=unsplash&utm_medium=referral&utm_content=creditCopyText">Unsplash</a>

# %% [markdown]
# ### Data Understanding
#
# Each record (row) in this dataset represents a home that was sold in Ames, IA.
#
# Each feature (column) in this dataset is some attribute of that home sale. You can view the file `data/data_description.txt` in this repository for a full explanation of all variables in this dataset — 80 columns in total.
#
# We are going to focus on the following features:
#
# **SalePrice**: `Sale price of the house in dollars`
#
# **TotRmsAbvGrd**: `Total rooms above grade (does not include bathrooms)`
#
# **OverallCond**: `Rates the overall condition of the house`
# ```
#        10	Very Excellent
#        9	 Excellent
#        8	 Very Good
#        7	 Good
#        6	 Above Average
#        5	 Average
#        4	 Below Average
#        3	 Fair
#        2	 Poor
#        1	 Very Poor
# ```
#
# **YrSold**: `Year Sold (YYYY)`
#
# **YearBuilt**: `Original construction date`
#
# **LandSlope**: `Slope of property`
# ```
#        Gtl	Gentle slope
#        Mod	Moderate Slope
#        Sev	Severe Slope
# ```

# %% [markdown]
# ### Requirements
#
# In this lab you will use your data munging and visualization skills to conduct an exploratory analysis of the dataset.
#
# #### 1. Load the Dataset with Pandas
#
# Import pandas with the standard alias `pd` and load the data into a dataframe with the standard name `df`.
#
# #### 2. Explore Data Distributions
#
# Produce summary statistics, visualizations, and interpretive text describing the distributions of `SalePrice`, `TotRmsAbvGrd`, and `OverallCond`.
#
# #### 3. Explore Differences between Subsets
#
# Separate the data into subsets based on `OverallCond`, then demonstrate how this split impacts the distribution of `SalePrice`.
#
# #### 4. Explore Correlations
#
# Find the features that have the strongest positive and negative correlations with `SalePrice`, and produce plots representing these relationships.
#
# #### 5. Engineer and Explore a New Feature
#
# Create a new feature `Age`, which represents the difference between the year sold and the year built, and plot the relationship between the age and sale price.

# %% [markdown]
# ### **For brief non_technical presentation click on this** [link](https://docs.google.com/presentation/d/1gNNkrFPmtcpGpMGtEyBV4gSw1iG9tH0PiuoxEXguRRE/edit?usp=sharing)

# %% [markdown]
# ## 1. Load the Dataset with Pandas
# ### load the data description.txt data set and the ames.csv
# In the cell below, import:
# * `pandas` with the standard alias `pd`
# * `matplotlib.pyplot` with the standard alias `plt`
#
# And set `%matplotlib inline` so the graphs will display immediately below the cell that creates them.

# %%
#import pandas library
import pandas as pd
#import visualizing library
import matplotlib.pyplot as plt
#write a code that will show the plots within the dataset
# %matplotlib inline

# %% [markdown]
# Now, use pandas to open the file located at `data/ames.csv` ([documentation here](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html)). Specify the argument `index_col=0` in order to avoid creating an extra `Id` column. Name the resulting dataframe `df`.

# %%
df = pd.read_csv('data/ames.csv', index_col=0)
df
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1             60       RL         65.0     8450   Pave   NaN      Reg
# 2             20       RL         80.0     9600   Pave   NaN      Reg
# 3             60       RL         68.0    11250   Pave   NaN      IR1
# 4             70       RL         60.0     9550   Pave   NaN      IR1
# 5             60       RL         84.0    14260   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# Id                                    ...
# ...

# %% [markdown]
# The following code checks that you loaded the data correctly:

# %%
# Run this cell without changes

# Check that df is a dataframe
assert type(df) == pd.DataFrame

# Check that there are the correct number of rows
assert df.shape[0] == 1460

# Check that there are the correct number of columns
# (if this crashes, make sure you specified `index_col=0`)
assert df.shape[1] == 80

# %% [markdown]
# Inspect the contents of the dataframe:

# %%
# Run this cell without changes to check the dataframe
df
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1             60       RL         65.0     8450   Pave   NaN      Reg
# 2             20       RL         80.0     9600   Pave   NaN      Reg
# 3             60       RL         68.0    11250   Pave   NaN      IR1
# 4             70       RL         60.0     9550   Pave   NaN      IR1
# 5             60       RL         84.0    14260   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# Id                                    ...
# ...

# %% [markdown]
# **Use the following attributes and methods to basically farmiliarize the dataframe structure:**
# + .info()
# + .shape
# + .columns
# + type()

# %%
# Run this cell without changes to check the basic analysis of the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1460 entries, 1 to 1460
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1460 non-null   int64
#  1   MSZoning       1460 non-null   object
#  2   LotFrontage    1201 non-null   float64
#  3   LotArea        1460 non-null   int64
#  4   Street         1460 non-null   object
#  5   Alley          91 non-null     object
#  6   LotShape       1460 non-null   object
#  7   LandContour    1460 non-null   object
#  8   Utilities      1460 non-null   object
#  9   LotConfig      1460 non-null   object
#  10  LandSlope      1460 non-null   object
#  11  Neighborhood   1460 non-null   object
#  12  Condition1     1460 non-null   object
#  13  Condition2     1460 non-null   object
#  14  BldgType       1460 non-null   object
#  15  HouseStyle     1460 non-null   object
#  16  OverallQual    1460 non-null   int64
# ...

# %%
#check the columns of the dataset
df.columns
# Out:
# Index(['MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street', 'Alley',
#        'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea',
#        'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
#        'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType', 'GarageYrBlt',
# ...

# %%
#check the number of rows and columns within the dataframe
df.shape
# Out:
# (1460, 80)

# %%
#check the type of the data
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# **For more farmiliarity of the dataset, i will conduct data cleaning for more reliability whereby  the data will be ready for analysis or modeling without introducing biases or inaccuracies. This is by checking the  if the data has duplicates, missing values or any other issues .**

# %%
# Write a code that prints out the number of missing values in the dataframe
missing_data = df.isnull().sum()  # Count missing values in each column
missing_data[missing_data > 0]  # Show only columns with missing values
# Out:
# LotFrontage      259
# Alley           1369
# MasVnrType       872
# MasVnrArea         8
# BsmtQual          37
# BsmtCond          37
# BsmtExposure      38
# BsmtFinType1      37
# BsmtFinType2      38
# Electrical         1
# FireplaceQu      690
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# PoolQC          1453
# Fence           1179
# MiscFeature     1406
# dtype: int64

# %% [markdown]
# **According to the output of the missing values within each column, the are some of the columns that have high values of missing data. This columns i will choose dropping strategy because its an easier way of cleaning them.**

# %%
# Write a code that prints out columns with more than 50% of missing values in the dataframe
df.dropna(axis=1, thresh=int(0.5*len(df)), inplace=True)

# %%
# Write a code thats prints out the columns remaining with the missing values
missing_data = df.isnull().sum()  # Count missing values in each column
missing_data[missing_data > 0]  # Show only columns with missing values
# Out:
# LotFrontage     259
# MasVnrArea        8
# BsmtQual         37
# BsmtCond         37
# BsmtExposure     38
# BsmtFinType1     37
# BsmtFinType2     38
# Electrical        1
# FireplaceQu     690
# GarageType       81
# GarageYrBlt      81
# GarageFinish     81
# GarageQual       81
# GarageCond       81
# dtype: int64

# %% [markdown]
# * For more understanding of the data before acting , i will check the information of every column so as to choose the right strategy to use to fill the missing values within the dataset. The strategies that i will use will be finding **mean and median values**for **numerical data** while for the **categorical data** i will find the **mode** of the column .

# %%
# Write a code that prints out the information of the columns that have missing values
df.loc[:, ['LotFrontage','MasVnrArea', 'BsmtQual','BsmtCond','BsmtExposure','BsmtFinType1','BsmtFinType2','Electrical','GarageType', 'GarageYrBlt', 'GarageFinish', 'GarageQual', 'GarageCond']]
# Out:
#       LotFrontage  MasVnrArea BsmtQual BsmtCond BsmtExposure BsmtFinType1  \
# Id
# 1            65.0       196.0       Gd       TA           No          GLQ
# 2            80.0         0.0       Gd       TA           Gd          ALQ
# 3            68.0       162.0       Gd       TA           Mn          GLQ
# 4            60.0         0.0       TA       Gd           No          ALQ
# 5            84.0       350.0       Gd       TA           Av          GLQ
# ...           ...         ...      ...      ...          ...          ...
# 1456         62.0         0.0       Gd       TA           No          Unf
# 1457         85.0       119.0       Gd       TA           No          ALQ
# 1458         66.0         0.0       TA       Gd           No          GLQ
# 1459         68.0         0.0       TA       TA           Mn          GLQ
# 1460         75.0         0.0       TA       TA           No          BLQ
#
# ...

# %% [markdown]
# + The `GarageQual`and the `GarageCond` tend to have the same data so i will find the mode of each column and compare them then fill their missing   values with the code.

# %%
# Write a code that prints out the mode of the GarageQual and the GarageCond then fill their missing values with the mode.
GarageQual_mode=df['GarageQual'].mode()[0] #the both outputs will be TA.
GarageCond_mode= df['GarageCond'].mode()[0]

# using  the modes fill the missing values of the two columns.
df['GarageQual'].fillna(GarageQual_mode, inplace=True)
df['GarageCond'].fillna(GarageCond_mode, inplace=True)
#verify is the missing values are still there
print(df[['GarageQual','GarageCond']].isnull().sum())
# Out:
# GarageQual    0
# GarageCond    0
# dtype: int64

# %% [markdown]
# + The `BsmtQual` ,`BsmtCond`,`BsmtExposure`,`BsmtFinType1`,`BsmtFinType2`,`GarageType`,`GarageFinish` columns ,i can replace the missing values with avalue **None** to avoid tampering with the data.

# %%
# Write a code that fills the missing values of the above column with the value None
df['BsmtQual'].fillna('NONE', inplace= True)
df['BsmtCond'].fillna('NONE', inplace= True)
df['BsmtExposure'].fillna('NONE', inplace= True)
df['BsmtFinType1'].fillna('NONE', inplace= True)
df['BsmtFinType2'].fillna('NONE', inplace= True)
df['GarageType'].fillna('NONE', inplace= True)
df['GarageFinish'].fillna('NONE', inplace= True)
df['FireplaceQu'].fillna('NONE', inplace= True)
#verify there are no missing values within the data columns above
#print(df[['BsmtQual','BsmtCond','BsmtExposure','BsmtFinType1','BsmtFinType2','GarageType','GarageFinish']].isnull().sum())

# %%
#so far lets check the remaining columns with the missing data
missing_data= df.isnull().sum()
missing_data[missing_data>0]
# Out:
# LotFrontage    259
# MasVnrArea       8
# Electrical       1
# GarageYrBlt     81
# dtype: int64

# %%
# for the electircal column fill the missing value with the mode.
data_fill=df['Electrical'].mode()[0]
df.fillna({'Electrical':data_fill }, inplace=True) #ordf['Electrical'].fillna(data_fill, inplace=True)

# %%
#write a code to fill the missing values of the MasVnrArea column with the median of the column
median_val=df['MasVnrArea'].median()
df.fillna({'MasVnrArea':median_val}, inplace=True)

# %% [markdown]
# **So far i have filled 3/4 of the missing values . The remaining columns  are `LotFrontage` and  `GarageYrBlt ` . Before acting on the matter i will decide to check into deatails about the two columns, for more clarity on choosing the right stategy to handle the missing values within them.**

# %%
# Write a code to drop rows  with the missing value the LotFrontage.
df.dropna(subset=['LotFrontage'], inplace=True)

# %%
#lastly the GarageYrBlt and YearBuilt seem to linger so i will conduct a group fumction and fill the missing data.
refill_data=df['GarageYrBlt']=df.groupby('YearBuilt')['GarageYrBlt'].apply(lambda x:x.mean())
df.fillna({'GarageYrBlt':refill_data},inplace=True)

# %%
# write a code that check if there are missing values once more.
df.isnull().sum()
# Out:
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
# Street           0
#                 ..
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# SalePrice        0
# Length: 75, dtype: int64

# %%
#write a code to check if there are duplicates.
duplicates= df.duplicated()
duplicates
# Out:
# Id
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
#         ...
# 1456    False
# 1457    False
# 1458    False
# 1459    False
# 1460    False
# Length: 1201, dtype: bool

# %% [markdown]
# **The dataset is ready for analysis its clean.**

# %%
df.head()
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# Id
# 1           60       RL         65.0     8450   Pave      Reg         Lvl
# 2           20       RL         80.0     9600   Pave      Reg         Lvl
# 3           60       RL         68.0    11250   Pave      IR1         Lvl
# 4           70       RL         60.0     9550   Pave      IR1         Lvl
# 5           60       RL         84.0    14260   Pave      IR1         Lvl
#
#    Utilities LotConfig LandSlope  ... EnclosedPorch 3SsnPorch ScreenPorch  \
# Id                                ...
# 1     AllPub    Inside       Gtl  ...             0         0           0
# 2     AllPub       FR2       Gtl  ...             0         0           0
# 3     AllPub    Inside       Gtl  ...             0         0           0
# 4     AllPub    Corner       Gtl  ...           272         0           0
# 5     AllPub       FR2       Gtl  ...             0         0           0
#
# ...

# %% [markdown]
# ## 2. Explore Data Distributions
#
# Write code to produce histograms showing the distributions of `SalePrice`, `TotRmsAbvGrd`, and `OverallCond`.
#
# Each histogram should have appropriate title and axes labels, as well as a black vertical line indicating the mean of the dataset. See the documentation for [plotting histograms](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.hist.html), [customizing axes](https://matplotlib.org/stable/api/axes_api.html#axis-labels-title-and-legend), and [plotting vertical lines](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.axvline.html#matplotlib.axes.Axes.axvline) as needed.

# %% [markdown]
# ### Sale Price
#
# In the cell below, produce a histogram for `SalePrice`.

# %%
# write a code that plots a histogram for the distribution of the SalePrice, TotRmsAbvGrd, and OverallCond.
# Define a function to plot histograms with mean line
def plot_histogram(data, column, title, x_label, y_label):
    data[column].plot(kind="hist", bins= 60, figsize =(10,6), color="green", edgecolor='black', alpha= 0.8)
    mean_value= data[column].mean()
    plt.axvline(mean_value, color='orange', linestyle='solid', linewidth=2, label=f'Mean: {mean_value:.2f}')
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(title)
    plt.legend()
    plt.show()

# %%
# Plot histograms for SalePrice, TotRmsAbvGrd, and OverallCond
plot_histogram(df , 'SalePrice', 'Distribution of SalePrice', 'SalePrice_values', 'Frequency')

# %% [markdown]
# Now, print out the mean, median, and standard deviation:

# %%
# print out the mean, median, and standard deviation of the sales price 
sales_price_mean = df['SalePrice'].mean()
sales_price_median= df['SalePrice'].median()
sales_price_std= df['SalePrice'].std()
print(f'The mean of the sales price is {sales_price_mean}')
print(f'The median of the sales price is  {sales_price_median}')
print(f'The standard deviation of the sales price is{sales_price_std}')
# Out:
# The mean of the sales price is 180770.48043297252
# The median of the sales price is  159500.0
# The standard deviation of the sales price is83389.51986550717

# %%
# write a code to confirm the above {mean and std} answers in the data column of the sales price,TotRmsAbvGrd and the OverallCond columns 
df.describe()
# Out:
#         MSSubClass  LotFrontage        LotArea  OverallQual  OverallCond  \
# count  1201.000000  1201.000000    1201.000000  1201.000000  1201.000000
# mean     57.198168    70.049958    9951.698585     6.122398     5.562032
# std      43.106427    24.284752    7924.353975     1.419216     1.094543
# min      20.000000    21.000000    1300.000000     1.000000     2.000000
# 25%      20.000000    59.000000    7420.000000     5.000000     5.000000
# 50%      50.000000    69.000000    9262.000000     6.000000     5.000000
# 75%      70.000000    80.000000   11249.000000     7.000000     6.000000
# max     190.000000   313.000000  215245.000000    10.000000     9.000000
#
#          YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1   BsmtFinSF2  ...  \
# count  1201.000000   1201.000000  1201.000000  1201.000000  1201.000000  ...
# mean   1970.580350   1985.189842   102.190674   427.063281    42.975853  ...
# std      31.750335     21.196948   185.082183   464.589556   154.493463  ...
# ...

# %% [markdown]
# **For deeper understanding of the data within the `sales price` , `TotRmsAbvGrd` and `OverallCond` columns we shall  be plotting a boxplot to check the outliers and relate them with the relationship of the data set and the outliers within the data for easier interpretation.**

# %%
#print out a box plot to check the outliers within the data set
df['SalePrice'].plot(kind='box', figsize=(8,5), vert=False, color='orange')
plt.title('BOXPLOT FOR THE SALES PRICES')
plt.xlabel('Price Values')
plt.show()

# %% [markdown]
# **My interpretation according to my analysis**
# + *Answer*
# 1. According to my analysis the mean is greater than the median due to the high price values of the few expensive houses known as the outliers.Secondly it seems that the price of many houses range within the mid_range or the more affordable zone.

# %% [markdown]
# ### Total Rooms Above Grade
#
# In the cell below, produce a histogram for `TotRmsAbvGrd`.

# %%
# use the earlier created function to print out the histogram of the TotRmsAbvGrd column
plot_histogram(df , 'TotRmsAbvGrd', 'Distribution of Total Rooms Above Ground', 'Total Rooms Above Ground', 'Frequency')

# %% [markdown]
# Now, print out the mean, median, and standard deviation:

# %%
# write a code that prints out the mean , median and the std of the TotRmsAbvGrd column.
TotRmsAbvGrd_mean = df['TotRmsAbvGrd'].mean()
TotRmsAbvGrd_median= df['TotRmsAbvGrd'].median()
TotRmsAbvGrd_std =df['TotRmsAbvGrd'].std()
print(f'The mean of total rooms above ground is {TotRmsAbvGrd_mean}')
print(f'The median of the total rooms above ground is {TotRmsAbvGrd_median}')
print(f'The standard deviation of the total rooms above ground is {TotRmsAbvGrd_std}')
# Out:
# The mean of total rooms above ground is 6.535387177352207
# The median of the total rooms above ground is 6.0
# The standard deviation of the total rooms above ground is 1.6296078375288434

# %%
#print out a box plot to check the outliers within the data set
df['TotRmsAbvGrd'].plot(kind='box', figsize=(8,5) ,color='orange')
plt.title('BOXPLOT FOR THE TOTAL ROOMS ABOVE GROUND ')
plt.ylabel('Total Values')
plt.show()

# %% [markdown]
# In the cell below, interpret the above information.

# %% [markdown]
# **My interpretation according to the total rooms above ground**
# + *My Answer*
# 2. According to my analysis the mean is slightly higher than the median suggesting that majority of the properties have number of rooms  within the range of **6.52 ± 1.63** hence few of them have more number of rooms than the rest leading to a slightly high calculation of the mean.

# %% [markdown]
# ### Overall Condition
#
# In the cell below, produce a histogram for `OverallCond`.

# %%
# writ a code that prints out the histogram of the OverallCond column
#use the earlier created function to print out the histogram
plot_histogram(df , 'OverallCond', 'Distribution of Overall Condition', 'OverallCond', 'Frequency')

# %% [markdown]
# Now, print out the mean, median, and standard deviation:

# %%
# write a code that prints out the mean, median and the std of the Overallcond column
Overallcond_mean =df['OverallCond'].mean()
Overallcond_median=df['OverallCond'].median()
Overallcond_std=df['OverallCond'].std()
print(f'The overall condition mean is {Overallcond_mean}' )
print(f'The overall condition median is{Overallcond_median}')
print(f'The overall condition standard deviation is{Overallcond_std}')
# Out:
# The overall condition mean is 5.56203164029975
# The overall condition median is5.0
# The overall condition standard deviation is1.0945427670941124

# %%
#print out a box plot to check the outliers within the data set
df['OverallCond'].plot(kind='box', figsize=(8,5) ,color='orange',vert=False)
plt.title('BOXPLOT FOR THE OVERALL CONDITION')
plt.xlabel('Condition Values')
plt.show()

# %% [markdown]
# In the cell below, interpret the above information.

# %% [markdown]
# **My interpretation according to my analysis**
# + *answer*
#
# 3. According to my analysis ,the small standard deviation indicates that the overall condition ratings are fairly consistent across the dataset, with few properties having very low or very high ratings hence it implies that most properties are in an average to slightly above average condition.

# %% [markdown]
# ## 3. Explore Differences between Subsets
#
# As you might have noted in the previous step, the overall condition of the house seems like we should treat it as more of a categorical variable, rather than a numeric variable.
#
# One useful way to explore a categorical variable is to create subsets of the full dataset based on that categorical variable, then plot their distributions based on some other variable. Since this dataset is traditionally used for predicting the sale price of a house, let's use `SalePrice` as that other variable.
#
# In the cell below, create three variables, each of which represents a record-wise subset of `df` (meaning, it has the same columns as `df`, but only some of the rows).
#
# * `below_average_condition`: home sales where the overall condition was less than 5
# * `average_condition`: home sales where the overall condition was exactly 5
# * `above_average_condition`: home sales where the overall condition was greater than 5

# %%
#write a code that calculates the below,average and above average conditions of the OverallCond column
below_average_condition =df[df['OverallCond']<5]
average_condition = df[df['OverallCond']==5]
above_average_condition = df[df['OverallCond']>5]

# %% [markdown]
# The following code checks that you created the subsets correctly:

# %%
# Run this cell without changes

# Check that all of them still have 80 columns
assert below_average_condition.shape[1] == 80
assert average_condition.shape[1] == 80
assert above_average_condition.shape[1] == 80

# Check the numbers of rows of each subset
assert below_average_condition.shape[0] == 88
assert average_condition.shape[0] == 821
assert above_average_condition.shape[0] == 551
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[135], line 4
#       1 # Run this cell without changes
#       2
#       3 # Check that all of them still have 80 columns
# ----> 4 assert below_average_condition.shape[1] == 80
#       5 assert average_condition.shape[1] == 80
#       6 assert above_average_condition.shape[1] == 80
#
# AssertionError:

# %% [markdown]
# The following code will produce a plot of the distributions of sale price for each of these subsets:

# %%
# Run this cell without changes

# Set up plot
fig, ax = plt.subplots(figsize=(15,5))

# Create custom bins so all are on the same scale
bins = range(df["SalePrice"].min(), df["SalePrice"].max(), int(df["SalePrice"].median()) // 20)

# Plot three histograms, with reduced opacity (alpha) so we
# can see them overlapping
ax.hist(
    x=above_average_condition["SalePrice"],
    label="above average condition",
    bins=bins,
    color="blue",
    alpha=0.5
)
ax.hist(
    x=average_condition["SalePrice"],
    label="average condition",
    bins=bins,
    color="green",
    alpha=0.3
)
ax.hist(
    x=below_average_condition["SalePrice"],
    label="below average condition",
    bins=bins,
    color="yellow",
    alpha=0.5
)

# Customize labels
ax.set_title("Distributions of Sale Price Grouped by Condition")
ax.set_xlabel("Sale Price")
ax.set_ylabel("Number of houses")
ax.legend()
plt.show()

# %% [markdown]
# #### For deeper understanging i will conduct a groupby function on the `OverallCond` and the `SalePrice` columns the find the mean of saleprice for each Overallcondition.this will enable me to have a vivid picture of the conditions and the saleprice of the houses in Ames Housing dataset.

# %%
# Write a code using the Groupby function to group the OverallCond by SalePrice
Mean_price_tag= df.groupby(df['OverallCond'])['SalePrice'].mean()
Mean_price_tag
# Out:
# OverallCond
# 2    141986.400000
# 3     95405.550000
# 4    119001.978261
# 5    205561.647661
# 6    151429.689320
# 7    150046.696970
# 8    157107.083333
# 9    202026.666667
# Name: SalePrice, dtype: float64

# %%
#print out a barchart using the data above and the matplotlib library.
plt.figure(figsize=(10,6))
plt.bar(Mean_price_tag.index.astype(str), Mean_price_tag.values, color='green', edgecolor='black')
plt.title("Average SalePrice by OverallCond")
plt.xlabel("Overall Condition" )
plt.ylabel("Average SalePrice")
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# Interpret the plot above. What does it tell us about these overall condition categories, and the relationship between overall condition and sale price? Is there anything surprising?

# %% [markdown]
# **My interpretation according to the analysis.**
# + *Answer*
# + 1. According to the analysis, the houses with the Average and Above_average conditions, have a high sale price than the once below_average.

# %% [markdown]
# ## 4. Explore Correlations
#
# To understand more about what features of these homes lead to higher sale prices, let's look at some correlations. We'll return to using the full `df`, rather than the subsets.
#
# In the cell below, print out both the name of the column and the Pearson correlation for the column that is ***most positively correlated*** with `SalePrice` (other than `SalePrice`, which is perfectly correlated with itself).
#
# We'll only check the correlations with some kind of numeric data type.
#
# You can import additional libraries, although it is possible to do this just using pandas.

# %%
numerical_df = df.select_dtypes(include=['number']).columns
numerical_df
# Out:
# Index(['MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2',
#        'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces',
#        'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal',
#        'MoSold', 'YrSold', 'SalePrice', 'Age'],
#       dtype='object')

# %%
# Get only numeric columns
numeric_df = df.select_dtypes(include=['number'])

# Calculate the correlation of all numeric columns with 'SalePrice'
correlations_with_saleprice = numeric_df.corr()['SalePrice'].drop('SalePrice')

# Find the column with the highest positive correlation
max_corr_column = correlations_with_saleprice.idxmax()
max_corr_value = correlations_with_saleprice.max()

print(f"The column most positively correlated with SalePrice is '{max_corr_column}' with a Pearson correlation of {max_corr_value:.4f}")
# Out:
# The column most positively correlated with SalePrice is 'OverallQual' with a Pearson correlation of 0.7910

# %% [markdown]
# Now, find the ***most negatively correlated*** column:

# %%
# Write a code that prints out the  most negatively correlated 
# Get only numeric columns
numeric_df = df.select_dtypes(include=['number'])

# Calculate the correlation of all numeric columns with 'SalePrice'
correlations_with_saleprice = numeric_df.corr()['SalePrice'].drop('SalePrice')

# Find the column with most negative correlation
min_corr_column = correlations_with_saleprice.idxmin()
min_corr_value = correlations_with_saleprice.min()

print(f"The column most negatively correlated with SalePrice is '{min_corr_column}' with a Pearson correlation of {min_corr_value:.4f}")
# Out:
# The column most negatively correlated with SalePrice is 'KitchenAbvGr' with a Pearson correlation of -0.1359

# %% [markdown]
# Once you have your answer, edit the code below so that it produces a box plot of the relevant columns.

# %%
# Replace None with appropriate code

import seaborn as sns

fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(15,5))

# Plot distribution of column with highest correlation
sns.boxplot(
    x=df['OverallQual'],
    y=df["SalePrice"],
    ax=ax1
)
# Plot distribution of column with most negative correlation
sns.boxplot(
    x=df['KitchenAbvGr'],
    y=df["SalePrice"],
    ax=ax2
)

# Customize labels
ax1.set_title('Distribution of OverallQual with SalePrice as highest correlation')
ax1.set_xlabel('OverallQual')
ax1.set_ylabel("Sale Price")
ax2.set_title('Distribution of KitchenAbvGr with SalePrice as most negative correlation')
ax2.set_xlabel('KitchenAbvGr')
ax2.set_ylabel("Sale Price")
plt.show()

# %%
# plot a scatter plot to analyse the numerical columns and there correlations with the SalePrice.
# Select numerical columns
numerical_df = df.select_dtypes(include=['number']).columns

# Set up the grid size for subplots
num_cols = len(numerical_df) - 1  # Exclude 'SalePrice' itself
num_rows = (num_cols // 3) + 1  # Adjust for 3 plots per row

# Create the subplots
fig, axes = plt.subplots(num_rows, 3, figsize=(14, num_rows * 5))
axes = axes.flatten()  # Flatten the grid of axes for easy iteration

# Iterate through numerical df and plot scatterplots
for i, col in enumerate(numerical_df):
    if col != 'SalePrice':  # Skip 'SalePrice'
        sns.scatterplot(x=col, y='SalePrice', data=df, ax=axes[i])
        axes[i].set_title(f'SalePrice vs {col}')
        axes[i].set_xlabel(col)
        axes[i].set_ylabel('SalePrice')

# Remove empty subplots (if any)
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %% [markdown]
# Interpret the results below. Consult `data/data_description.txt` as needed.

# %% [markdown]
# #### My interpretation .
# *Answer*
# * 1. According to the analysis,the higher the correlation of which i may refer to it as a positive correlation, the higher the Sale price value while the lower the correlation or negative correlation, the lower the Sale price value.

# %% [markdown]
# ## 5. Engineer and Explore a New Feature
#
# Here the code is written for you, all you need to do is interpret it.
#
# We note that the data spans across several years of sales:

# %%
# Run this cell without changes
data_sorted=df["YrSold"].value_counts().sort_index()
data_sorted
# Out:
# YrSold
# 2006    314
# 2007    329
# 2008    304
# 2009    338
# 2010    175
# Name: count, dtype: int64

# %% [markdown]
# Maybe we can learn something interesting from the age of the home when it was sold. This uses information from the `YrBuilt` and `YrSold` columns, but represents a truly distinct feature.

# %%
# Run this cell without changes
data=data_sorted
# Make a new column, Age
df["Age"] = df["YrSold"] - df["YearBuilt"]

# Set up plot
fig, ax = plt.subplots(figsize=(15,5))

# Plot Age vs. SalePrice
ax.scatter(df["Age"], df["SalePrice"], alpha=0.3, color="green")

#add a line plot within the scatter plot to show the trend of the correlation
sns.regplot(x=df["Age"], y=df["SalePrice"], data=data_sorted ,scatter=False, ax=ax, line_kws={"color": "blue", "linewidth": 2}, label="Trend Line")
ax.set_title("Home Age vs. Sale Price")
ax.set_xlabel("Age of Home at Time of Sale")
ax.set_ylabel("Sale Price")
plt.legend()
plt.show()

# %% [markdown]
# Interpret this plot below:

# %% [markdown]
# Replace None with appropriate text
# + **According to the the analysis , the trend is moving downwards hence the correlation of the home age and sale price columns is negative .This means that the higher the number of age , the lower the sale price.**

# %% [markdown]
# ## Summary
# This project focused on analyzing the Ames Housing Dataset to identify factors influencing housing prices and build predictive aspects for sale prices. The dataset underwent extensive preprocessing, including cleaning missing values, correlating numerical features or columns with the target variable (SalePrice),addressing categorical variables by replacing missing values with **None** and addressing more understanding motives on the `TotRmsAbvGrd`and `OverallCond ` columns. Key insights were derived from analyzing feature correlations, which guided the selection of important predictors. These efforts enhanced great predicts for housing prices accurately.

# %% [markdown]
# ## Recommendations
# Despite having conducted a few analyzations, there are improvements that could be made still be made for the model of the project. They are:
# * **Handle Outliers**: When analyzing the TotRmsAbvGrd TotRmsAbvGrd and the SalePrice columns i realized the outliers but did not do anything                            about them since i used them to interprate my suggestions.to improve the project, techniques such as      removal, transformation  and etc could be applied.
# * **Filling of the categorical columns with appropriate information during cleaning**:When cleaning the data ,*None* was effective for this    iteration,but for more improvement motives one can deepen the understanding of the columns and replace with appropriate data.
# * **Feature engineering**:Investigate  other opportunities in  creating new features that might better capture the underlying trends in the dataset, such as combining existing features or generating interaction terms.
# * **Document Further insights**:  Continue visualizatizing and creating statistical summaries to communicate findings effectively, especially when presenting resultsfor both technical stakeholders and non-technical stekeholders .

# %% [markdown]
# ## conclusions
# This project provided valuable insights into the factors affecting housing prices in Ames,  by analyzing the Ames Housing Dataset. Through preprocessing and feature exploration, key predictors of SalePrice were identified, while visualizations and statistical analysis helped uncover underlying patterns within the data. Although certain aspects like outlier handling were not fully addressed, the project successfully highlighted areas for further investigation and improvement.
